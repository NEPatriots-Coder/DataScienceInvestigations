# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

# Assuming we have our cleaned data from previous analysis
# df_ml_clean should be available from the previous notebook

print("🔍 DETAILED ANALYSIS: PLANNERS & PARTS")
print("=" * 50)
# Out:
# 🔍 DETAILED ANALYSIS: PLANNERS & PARTS
# ==================================================

# %%
file_path = '/home/alaskapycoder/DataScience/MAY_CYCLE_COUNT.xlsx'
sheet_name = 'WestFargo'

# %%
try:
    # Load raw data
    df_raw = pd.read_excel(file_path, sheet_name=sheet_name)
    print(f"✅ Loaded {df_raw.shape[0]} rows from {sheet_name}")
    
    # Clean column names
    df_raw.columns = df_raw.columns.str.strip()
    print(f"📋 Columns: {list(df_raw.columns)}")
    
except Exception as e:
    print(f"❌ Error loading file: {e}")
    print("Please ensure MAY_CYCLE_COUNT.xlsx is in the current directory")

# %%
# Clean and prepare data for analysis
print("\n🧹 CLEANING AND PREPARING DATA")
print("=" * 35)

# Remove unwanted columns (as specified in original request)
columns_to_drop = ['NOTES', 'REASON FOR VARIANCE']
df_clean = df_raw.drop(columns=[col for col in columns_to_drop if col in df_raw.columns], errors='ignore')

# Remove rows with missing critical data
df_clean = df_clean.dropna(subset=['VARIANCE', 'PLANNER', 'Product number']).copy()
# Out:
# ✅ Loaded 572 rows from WestFargo
# 📋 Columns: ['DATE', 'Product number', 'DESCRIPTION', 'LOCATION', 'START', 'END', 'DIFFERENCE', 'PLANNER', 'VARIANCE', 'NOTES', 'REASON FOR VARIANCE']
#
# 🧹 CLEANING AND PREPARING DATA
# ===================================

# %%
columns_to_drop = ['NOTES', 'REASON FOR VARIANCE']
df_clean = df_raw.drop(columns=[col for col in columns_to_drop if col in df_raw.columns], errors='ignore')

# Remove rows with missing critical data
df_clean = df_clean.dropna(subset=['VARIANCE', 'PLANNER', 'Product number']).copy()

# Create key calculated fields
df_clean['ABS_VARIANCE'] = abs(df_clean['VARIANCE'])
df_clean['ABS_DIFFERENCE'] = abs(df_clean['DIFFERENCE'])

# %%
def categorize_variance(variance):
    abs_var = abs(variance)
    if abs_var <= 0.05:  # 5% threshold
        return 'LOW'
    elif abs_var <= 0.15:  # 15% threshold
        return 'MEDIUM'
    else:
        return 'HIGH'

df_clean['VARIANCE_CATEGORY'] = df_clean['VARIANCE'].apply(categorize_variance)

# Clean planner names (remove extra spaces)
df_clean['PLANNER'] = df_clean['PLANNER'].str.strip()
df_clean['Product number'] = df_clean['Product number'].str.strip()

print(f"✅ Data cleaned and prepared")
print(f"📊 Final dataset shape: {df_clean.shape}")
print(f"🎯 Variance categories: {df_clean['VARIANCE_CATEGORY'].value_counts()}")

# Save this as our working dataframe
df_analysis = df_clean.copy()

# %%
# Quick data validation
print("\n🔍 DATA VALIDATION")
print("=" * 20)

print("Key Statistics:")
print(f"  • Total items: {len(df_analysis)}")
print(f"  • Unique planners: {df_analysis['PLANNER'].nunique()}")
print(f"  • Unique products: {df_analysis['Product number'].nunique()}")
print(f"  • Date range: {df_analysis['DATE'].min()} to {df_analysis['DATE'].max()}")

print(f"\nVariance Distribution:")
for category in ['LOW', 'MEDIUM', 'HIGH']:
    count = (df_analysis['VARIANCE_CATEGORY'] == category).sum()
    pct = count / len(df_analysis) * 100
    print(f"  • {category}: {count} items ({pct:.1f}%)")
# Out:
# ✅ Data cleaned and prepared
# 📊 Final dataset shape: (255, 12)
# 🎯 Variance categories: VARIANCE_CATEGORY
# LOW       162
# HIGH       66
# MEDIUM     27
# Name: count, dtype: int64
#
# 🔍 DATA VALIDATION
# ====================
# Key Statistics:
#   • Total items: 255
#   • Unique planners: 10
#   • Unique products: 186
#   • Date range: 2025-05-15 00:00:00 to 2025-05-29 00:00:00
#
# Variance Distribution:
#   • LOW: 162 items (63.5%)
#   • MEDIUM: 27 items (10.6%)
#   • HIGH: 66 items (25.9%)

# %%
planner_stats = df_analysis.groupby('PLANNER').agg({
    'Product number': 'count',  # Total items managed
    'ABS_VARIANCE': ['mean', 'std', 'max'],  # Variance statistics
    'DIFFERENCE': ['mean', 'std'],  # Difference statistics
    'START': ['mean', 'sum'],  # Inventory value managed
}).round(4)

# Flatten column names
planner_stats.columns = ['Total_Items', 'Avg_Abs_Variance', 'Std_Variance', 'Max_Variance',
                        'Avg_Difference', 'Std_Difference', 'Avg_Inventory_Value', 'Total_Inventory_Value']

# Add high variance count and rate
high_variance_counts = df_analysis.groupby('PLANNER')['VARIANCE_CATEGORY'].apply(
    lambda x: (x == 'HIGH').sum()
).rename('High_Variance_Count')

planner_stats = planner_stats.join(high_variance_counts)
planner_stats['High_Variance_Rate'] = (planner_stats['High_Variance_Count'] / 
                                      planner_stats['Total_Items'] * 100).round(1)

# Calculate overall risk score
planner_stats['Risk_Score'] = (planner_stats['Avg_Abs_Variance'] * 100 + 
                              planner_stats['High_Variance_Rate']).round(1)

# Sort by risk score
planner_stats = planner_stats.sort_values('Risk_Score', ascending=False)

print("PLANNER PERFORMANCE SUMMARY:")
print("=" * 30)
display_cols = ['Total_Items', 'High_Variance_Count', 'High_Variance_Rate', 'Avg_Abs_Variance', 'Risk_Score']
print(planner_stats[display_cols])

# %%
# Categorize planners by risk level
print("\n🚨 PLANNER RISK CATEGORIES")
print("=" * 30)
# Out:
# PLANNER PERFORMANCE SUMMARY:
# ==============================
#          Total_Items  High_Variance_Count  High_Variance_Rate  \
# PLANNER
# 01BIFA             1                    1               100.0
# 01LTEA            15                    5                33.3
# 01TG1A            41                   19                46.3
# 01LAMA            16                   10                62.5
# 01FVWA             5                    3                60.0
# 01SPRA            12                    4                33.3
# 01HDWA            77                   21                27.3
# 01PRSA             4                    1                25.0
# 01TRKA            72                    2                 2.8
# 01SHPA             8                    0                 0.0
#
#          Avg_Abs_Variance  Risk_Score
# PLANNER
# 01BIFA             2.0000       300.0
# 01LTEA             2.3081       264.1
# 01TG1A             0.8924       135.5
# 01LAMA             0.3853       101.0
# 01FVWA             0.3696        97.0
# 01SPRA             0.3140        64.7
# 01HDWA             0.3390        61.2
# 01PRSA             0.3501        60.0
# 01TRKA             0.0093         3.7
# 01SHPA             0.0205         2.1
#
# 🚨 PLANNER RISK CATEGORIES
# ==============================

# %%
high_risk_threshold = planner_stats['Risk_Score'].quantile(0.75)
medium_risk_threshold = planner_stats['Risk_Score'].quantile(0.5)

high_risk_planners = []
medium_risk_planners = []
low_risk_planners = []

for planner, row in planner_stats.iterrows():
    if row['Risk_Score'] > high_risk_threshold:
        risk_level = "🔴 HIGH RISK"
        high_risk_planners.append(planner)
    elif row['Risk_Score'] > medium_risk_threshold:
        risk_level = "🟡 MEDIUM RISK" 
        medium_risk_planners.append(planner)
    else:
        risk_level = "🟢 LOW RISK"
        low_risk_planners.append(planner)
    
    print(f"\n{planner} - {risk_level}")
    print(f"  📊 Manages {int(row['Total_Items'])} items")
    print(f"  📈 High variance rate: {row['High_Variance_Rate']:.1f}%")
    print(f"  📉 Average variance: {row['Avg_Abs_Variance']:.1%}")
    print(f"  ⚡ Risk score: {row['Risk_Score']:.1f}")
# Out:
# 01BIFA - 🔴 HIGH RISK
#   📊 Manages 1 items
#   📈 High variance rate: 100.0%
#   📉 Average variance: 200.0%
#   ⚡ Risk score: 300.0
#
# 01LTEA - 🔴 HIGH RISK
#   📊 Manages 15 items
#   📈 High variance rate: 33.3%
#   📉 Average variance: 230.8%
#   ⚡ Risk score: 264.1
#
# 01TG1A - 🔴 HIGH RISK
#   📊 Manages 41 items
#   📈 High variance rate: 46.3%
#   📉 Average variance: 89.2%
#   ⚡ Risk score: 135.5
#
# 01LAMA - 🟡 MEDIUM RISK
#   📊 Manages 16 items
#   📈 High variance rate: 62.5%
#   📉 Average variance: 38.5%
#   ⚡ Risk score: 101.0
#
# 01FVWA - 🟡 MEDIUM RISK
#   📊 Manages 5 items
#   📈 High variance rate: 60.0%
#   📉 Average variance: 37.0%
#   ⚡ Risk score: 97.0
#
# 01SPRA - 🟢 LOW RISK
#   📊 Manages 12 items
#   📈 High variance rate: 33.3%
#   📉 Average variance: 31.4%
#   ⚡ Risk score: 64.7
#
# 01HDWA - 🟢 LOW RISK
#   📊 Manages 77 items
#   📈 High variance rate: 27.3%
#   📉 Average variance: 33.9%
#   ⚡ Risk score: 61.2
#
# 01PRSA - 🟢 LOW RISK
#   📊 Manages 4 items
#   📈 High variance rate: 25.0%
#   📉 Average variance: 35.0%
#   ⚡ Risk score: 60.0
#
# 01TRKA - 🟢 LOW RISK
#   📊 Manages 72 items
#   📈 High variance rate: 2.8%
#   📉 Average variance: 0.9%
#   ⚡ Risk score: 3.7
#
# 01SHPA - 🟢 LOW RISK
#   📊 Manages 8 items
#   📈 High variance rate: 0.0%
#   📉 Average variance: 2.1%
#   ⚡ Risk score: 2.1

# %%
print("\n🎯 ITEMS REQUIRING IMMEDIATE ATTENTION")
print("=" * 45)

# Get high priority items (HIGH variance)
high_priority = df_analysis[df_analysis['VARIANCE_CATEGORY'] == 'HIGH'].copy()
high_priority = high_priority.sort_values('ABS_VARIANCE', ascending=False)

print(f"🔴 HIGH PRIORITY - RECOUNT REQUIRED ({len(high_priority)} items)")
print("=" * 60)

for idx, (_, item) in enumerate(high_priority.iterrows()):
    print(f"\n{idx+1:2d}. PART: {item['Product number']}")
    print(f"     DESCRIPTION: {item['DESCRIPTION']}")
    print(f"     PLANNER: {item['PLANNER']}")
    print(f"     EXPECTED: {int(item['START']):,} | FOUND: {int(item['END']):,} | DIFF: {int(item['DIFFERENCE']):,}")
    print(f"     VARIANCE: {item['VARIANCE']:.1%} | ACTION: IMMEDIATE RECOUNT")

# %%
# Get medium priority items
medium_priority = df_analysis[df_analysis['VARIANCE_CATEGORY'] == 'MEDIUM'].copy()
medium_priority = medium_priority.sort_values('ABS_VARIANCE', ascending=False)

print(f"\n🟡 MEDIUM PRIORITY - REVIEW RECOMMENDED ({len(medium_priority)} items)")
print("=" * 65)

for idx, (_, item) in enumerate(medium_priority.head(10).iterrows()):  # Show top 10
    print(f"\n{idx+1:2d}. PART: {item['Product number']}")
    print(f"     DESCRIPTION: {item['DESCRIPTION']}")
    print(f"     PLANNER: {item['PLANNER']}")
    print(f"     EXPECTED: {int(item['START']):,} | FOUND: {int(item['END']):,} | DIFF: {int(item['DIFFERENCE']):,}")
    print(f"     VARIANCE: {item['VARIANCE']:.1%} | ACTION: SPOT CHECK")

if len(medium_priority) > 10:
    print(f"\n... and {len(medium_priority) - 10} more medium priority items")
# Out:
# 🎯 ITEMS REQUIRING IMMEDIATE ATTENTION
# =============================================
# 🔴 HIGH PRIORITY - RECOUNT REQUIRED (66 items)
# ============================================================
#
#  1. PART: EVWS112
#      DESCRIPTION: VINYL WINDOW SCREW 1 1/2IN
#      PLANNER: 01LTEA
#      EXPECTED: 152,950 | FOUND: 4,750,000 | DIFF: 4,597,050
#      VARIANCE: 3005.6% | ACTION: IMMEDIATE RECOUNT
#
#  2. PART: TG084L194
#      DESCRIPTION: 16FT 2IN 2TG BOTTOM EXTRUSION
#      PLANNER: 01TG1A
#      EXPECTED: -16 | FOUND: 80 | DIFF: 96
#      VARIANCE: -600.0% | ACTION: IMMEDIATE RECOUNT
#
#  3. PART: TG018L146
#      DESCRIPTION: 12FT 2IN 2TG TOP EXTRUSION
#      PLANNER: 01TG1A
#      EXPECTED: -37 | FOUND: 163 | DIFF: 200
#      VARIANCE: -540.5% | ACTION: IMMEDIATE RECOUNT
#
#  4. PART: BBAM18W
#      DESCRIPTION: 18-W ANGLE MT LEG OUT BAG 18HI
#      PLANNER: 01HDWA
#      EXPECTED: 5 | FOUND: 32 | DIFF: 27
#      VARIANCE: 540.0% | ACTION: IMMEDIATE RECOUNT
#
#  5. PART: BBAM16S
#      DESCRIPTION: 16-S ANGLE MT LEG IN BAG 16 HI
#      PLANNER: 01HDWA
#      EXPECTED: -1 | FOUND: 4 | DIFF: 5
#      VARIANCE: -500.0% | ACTION: IMMEDIATE RECOUNT
#
#  6. PART: nan
#      DESCRIPTION: 38 11/16 X 12 11/16-1/2
#      PLANNER: 01LTEA
#      EXPECTED: -3 | FOUND: 9 | DIFF: 12
#      VARIANCE: -400.0% | ACTION: IMMEDIATE RECOUNT
#
#  7. PART: TG084L194
#      DESCRIPTION: 16FT 2IN 2TG BOTTOM EXTRUSION
#      PLANNER: 01TG1A
#      EXPECTED: 9 | FOUND: 45 | DIFF: 36
#      VARIANCE: 400.0% | ACTION: IMMEDIATE RECOUNT
#
#  8. PART: nan
#      DESCRIPTION: 3/8 FLANGE NUT (RED)
#      PLANNER: 01HDWA
#      EXPECTED: -7,818 | FOUND: 21,350 | DIFF: 29,168
#      VARIANCE: -373.1% | ACTION: IMMEDIATE RECOUNT
#
#  9. PART: TG018L194
#      DESCRIPTION: 16FT 2IN 2TG TOP EXTRUSION
#      PLANNER: 01TG1A
#      EXPECTED: -36 | FOUND: 67 | DIFF: 103
#      VARIANCE: -286.1% | ACTION: IMMEDIATE RECOUNT
#
# 10. PART: LM312HM
#      DESCRIPTION: 312HM SGL CHANNEL COAX RECEIVR
#      PLANNER: 01BIFA
#      EXPECTED: -13 | FOUND: 13 | DIFF: 26
#      VARIANCE: -200.0% | ACTION: IMMEDIATE RECOUNT
#
# 11. PART: TG084L146
#      DESCRIPTION: 12FT 2N 2TG BOTTOM EXTRUSION
#      PLANNER: 01TG1A
#      EXPECTED: 103 | FOUND: 303 | DIFF: 200
#      VARIANCE: 194.2% | ACTION: IMMEDIATE RECOUNT
#
# 12. PART: TG3001L194
#      DESCRIPTION: 16FT2 3TG TOP EXTRUSION
#      PLANNER: 01TG1A
#      EXPECTED: -12 | FOUND: 10 | DIFF: 22
#      VARIANCE: -183.3% | ACTION: IMMEDIATE RECOUNT
#
# 13. PART: TG018L144
#      DESCRIPTION: 12FT 0IN 2TG TOP EXTRUSION
#      PLANNER: 01TG1A
#      EXPECTED: -47 | FOUND: 30 | DIFF: 77
#      VARIANCE: -163.8% | ACTION: IMMEDIATE RECOUNT
#
# 14. PART: 37560028RNC
#      DESCRIPTION: 375X6X28 RHW NO CONES
#      PLANNER: 01SPRA
#      EXPECTED: -5 | FOUND: 3 | DIFF: 8
#      VARIANCE: -160.0% | ACTION: IMMEDIATE RECOUNT
#
# 15. PART: 37560028LNC
#      DESCRIPTION: 375X6X28 LHW NO CONES
#      PLANNER: 01SPRA
#      EXPECTED: -5 | FOUND: 3 | DIFF: 8
#      VARIANCE: -160.0% | ACTION: IMMEDIATE RECOUNT
#
# 16. PART: 2008TG0800
#      DESCRIPTION: 8FT 0IN 2TG ASTRAGAL HOLDER
#      PLANNER: 01TG1A
#      EXPECTED: -18 | FOUND: 9 | DIFF: 27
#      VARIANCE: -150.0% | ACTION: IMMEDIATE RECOUNT
#
# 17. PART: E1743WSBFONID
#      DESCRIPTION: LP BACK FRAME ONLY PS
#      PLANNER: 01LTEA
#      EXPECTED: 292 | FOUND: 725 | DIFF: 433
#      VARIANCE: 148.3% | ACTION: IMMEDIATE RECOUNT
#
# 18. PART: G047X4687GLNA
#      DESCRIPTION: .047 x 4.687 GALVANIZED
#      PLANNER: 01PRSA
#      EXPECTED: -17,878 | FOUND: 7,159 | DIFF: 25,037
#      VARIANCE: -140.0% | ACTION: IMMEDIATE RECOUNT
#
# 19. PART: BBJB08W
#      DESCRIPTION: 8-J JAMB BRACKET  BAG 8 HI
#      PLANNER: 01HDWA
#      EXPECTED: -13 | FOUND: 5 | DIFF: 18
#      VARIANCE: -138.5% | ACTION: IMMEDIATE RECOUNT
#
# 20. PART: TG016L194
#      DESCRIPTION: 16FT2 3TG BOTTOM EXTRUSION
#      PLANNER: 01TG1A
#      EXPECTED: -32 | FOUND: 9 | DIFF: 41
#      VARIANCE: -128.1% | ACTION: IMMEDIATE RECOUNT
#
# 21. PART: 2008TG0802
#      DESCRIPTION: 8FT 2IN 2TG ASTRAGAL HOLDER
#      PLANNER: 01TG1A
#      EXPECTED: -36 | FOUND: 9 | DIFF: 45
#      VARIANCE: -125.0% | ACTION: IMMEDIATE RECOUNT
#
# 22. PART: TG016L170
#      DESCRIPTION: 14FT2 3TG BOTTOM EXTRUSION
#      PLANNER: 01TG1A
#      EXPECTED: -46 | FOUND: 11 | DIFF: 57
#      VARIANCE: -123.9% | ACTION: IMMEDIATE RECOUNT
#
# 23. PART: TG084L120
#      DESCRIPTION: 10FT 0IN 2TG BOTTOM EXTRUSION
#      PLANNER: 01TG1A
#      EXPECTED: -67 | FOUND: 9 | DIFF: 76
#      VARIANCE: -113.4% | ACTION: IMMEDIATE RECOUNT
#
# 24. PART: TG3001L194
#      DESCRIPTION: 16FT2 3TG TOP EXTRUSION
#      PLANNER: 01TG1A
#      EXPECTED: -87 | FOUND: 10 | DIFF: 97
#      VARIANCE: -111.5% | ACTION: IMMEDIATE RECOUNT
#
# 25. PART: TG018L120
#      DESCRIPTION: 10FT 0IN 2TG TOP EXTRUSION
#      PLANNER: 01TG1A
#      EXPECTED: -115 | FOUND: 12 | DIFF: 127
#      VARIANCE: -110.4% | ACTION: IMMEDIATE RECOUNT
#
# 26. PART: 1204R
#      DESCRIPTION: MINI WHS RAW SPACER BLOCK
#      PLANNER: 01HDWA
#      EXPECTED: 238 | FOUND: 0 | DIFF: -238
#      VARIANCE: -100.0% | ACTION: IMMEDIATE RECOUNT
#
# 27. PART: BB2PCSSR
#      DESCRIPTION: RESI 2PC SS HL/FV WOOD BLT BAG
#      PLANNER: 01HDWA
#      EXPECTED: 0 | FOUND: 1 | DIFF: 1
#      VARIANCE: 100.0% | ACTION: IMMEDIATE RECOUNT
#
# 28. PART: FV201BL220
#      DESCRIPTION: 18FT4 FV 2IN WIDE RAIL BLK
#      PLANNER: 01FVWA
#      EXPECTED: 26 | FOUND: 0 | DIFF: -26
#      VARIANCE: -100.0% | ACTION: IMMEDIATE RECOUNT
#
# 29. PART: TG084L192
#      DESCRIPTION: 16FT 0IN 2TG BOTTOM EXTRUSION
#      PLANNER: 01TG1A
#      EXPECTED: 0 | FOUND: 13 | DIFF: 13
#      VARIANCE: 100.0% | ACTION: IMMEDIATE RECOUNT
#
# 30. PART: TG018L194
#      DESCRIPTION: 16FT 2IN 2TG TOP EXTRUSION
#      PLANNER: 01TG1A
#      EXPECTED: 0 | FOUND: 32 | DIFF: 32
#      VARIANCE: 100.0% | ACTION: IMMEDIATE RECOUNT
#
# 31. PART: BBR1PCSSHL
#      DESCRIPTION: RESI 1PC SOLID BOLT BAG  HL
#      PLANNER: 01HDWA
#      EXPECTED: 2 | FOUND: 4 | DIFF: 2
#      VARIANCE: 100.0% | ACTION: IMMEDIATE RECOUNT
#
# 32. PART: OLD24X12GLS002
#      DESCRIPTION: OLD 24X12 ES 1/2X23 7/8X11 7/8
#      PLANNER: 01LTEA
#      EXPECTED: 1 | FOUND: 0 | DIFF: -1
#      VARIANCE: -100.0% | ACTION: IMMEDIATE RECOUNT
#
# 33. PART: 902C1109
#      DESCRIPTION: 5/32"-7X19-11'9" TORS CABLE
#      PLANNER: 01HDWA
#      EXPECTED: 0 | FOUND: 2 | DIFF: 2
#      VARIANCE: 100.0% | ACTION: IMMEDIATE RECOUNT
#
# 34. PART: BBMWRSP
#      DESCRIPTION: MINI-WHSE BB RESI 2IN TS/TG
#      PLANNER: 01HDWA
#      EXPECTED: 58 | FOUND: 0 | DIFF: -58
#      VARIANCE: -100.0% | ACTION: IMMEDIATE RECOUNT
#
# 35. PART: ES24218
#      DESCRIPTION: 1 7/8X24X218 ES INS W/TAPE
#      PLANNER: 01LAMA
#      EXPECTED: 154 | FOUND: 1 | DIFF: -153
#      VARIANCE: -99.4% | ACTION: IMMEDIATE RECOUNT
#
# 36. PART: 1206BLS
#      DESCRIPTION: MINI WHS SPACER BLOCK
#      PLANNER: 01HDWA
#      EXPECTED: 5 | FOUND: 161 | DIFF: 156
#      VARIANCE: 96.9% | ACTION: IMMEDIATE RECOUNT
#
# 37. PART: BBJB14W
#      DESCRIPTION: 14-J JAMB BRACKET BAG 14 HI
#      PLANNER: 01HDWA
#      EXPECTED: 12 | FOUND: 1 | DIFF: -11
#      VARIANCE: -91.7% | ACTION: IMMEDIATE RECOUNT
#
# 38. PART: ES24122
#      DESCRIPTION: 1 7/8X24X122 ES INS W/TAPE
#      PLANNER: 01LAMA
#      EXPECTED: 697 | FOUND: 92 | DIFF: -605
#      VARIANCE: -86.8% | ACTION: IMMEDIATE RECOUNT
#
# 39. PART: ES24122
#      DESCRIPTION: 1 7/8X24X122 ES INS W/TAPE
#      PLANNER: 01LAMA
#      EXPECTED: 24 | FOUND: 7 | DIFF: -17
#      VARIANCE: -70.8% | ACTION: IMMEDIATE RECOUNT
#
# 40. PART: ES24146
#      DESCRIPTION: 1 7/8X24X146 ES INS W/TAPE
#      PLANNER: 01LAMA
#      EXPECTED: 710 | FOUND: 244 | DIFF: -466
#      VARIANCE: -65.6% | ACTION: IMMEDIATE RECOUNT
#
# 41. PART: TG084L144
#      DESCRIPTION: 12FT 0IN 2TG BOTTOM EXTRUSION
#      PLANNER: 01TG1A
#      EXPECTED: 120 | FOUND: 197 | DIFF: 77
#      VARIANCE: 64.2% | ACTION: IMMEDIATE RECOUNT
#
# 42. PART: FV201BL196
#      DESCRIPTION: 16FT4 FV 2IN WIDE RAIL BLK
#      PLANNER: 01FVWA
#      EXPECTED: 85 | FOUND: 31 | DIFF: -54
#      VARIANCE: -63.5% | ACTION: IMMEDIATE RECOUNT
#
# 43. PART: CL3006L96
#      DESCRIPTION: 3 X 24 X 96 INSULATION
#      PLANNER: 01LAMA
#      EXPECTED: 172 | FOUND: 280 | DIFF: 107
#      VARIANCE: 62.3% | ACTION: IMMEDIATE RECOUNT
#
# 44. PART: SPCRBAG
#      DESCRIPTION: SPACER BAG 1 INCH
#      PLANNER: 01HDWA
#      EXPECTED: 5 | FOUND: 8 | DIFF: 3
#      VARIANCE: 60.0% | ACTION: IMMEDIATE RECOUNT
#
# 45. PART: ES24242
#      DESCRIPTION: 1 7/8X24X242 ES INS W/TAPE
#      PLANNER: 01LAMA
#      EXPECTED: 180 | FOUND: 77 | DIFF: -103
#      VARIANCE: -57.2% | ACTION: IMMEDIATE RECOUNT
#
# 46. PART: BBAM14W
#      DESCRIPTION: 14-W ANGLE MT LEG OUT BAG 14HI
#      PLANNER: 01HDWA
#      EXPECTED: 52 | FOUND: 23 | DIFF: -29
#      VARIANCE: -55.8% | ACTION: IMMEDIATE RECOUNT
#
# 47. PART: ES24170
#      DESCRIPTION: 1 7/8X24X170 ES INS W/TAPE
#      PLANNER: 01LAMA
#      EXPECTED: 662 | FOUND: 324 | DIFF: -338
#      VARIANCE: -51.1% | ACTION: IMMEDIATE RECOUNT
#
# 48. PART: BBAM14S
#      DESCRIPTION: 14-S ANGLE MT LEG IN BAG 14 HI
#      PLANNER: 01HDWA
#      EXPECTED: 32 | FOUND: 18 | DIFF: -14
#      VARIANCE: -43.8% | ACTION: IMMEDIATE RECOUNT
#
# 49. PART: ASTRETFOAM
#      DESCRIPTION: FOAM FOR ES RETAINER
#      PLANNER: 01LAMA
#      EXPECTED: 41,700 | FOUND: 23,700 | DIFF: -18,000
#      VARIANCE: -43.2% | ACTION: IMMEDIATE RECOUNT
#
# 50. PART: BB3X5WH
#      DESCRIPTION: 3 X 5 WHT/CLEAR BOLT BAG ONLY
#      PLANNER: 01HDWA
#      EXPECTED: 2,733 | FOUND: 3,418 | DIFF: 685
#      VARIANCE: 25.1% | ACTION: IMMEDIATE RECOUNT
#
# 51. PART: CPMT011B
#      DESCRIPTION: RH SWING ANGLED POST PLT 28IN
#      PLANNER: 01TRKA
#      EXPECTED: 36 | FOUND: 27 | DIFF: -9
#      VARIANCE: -25.0% | ACTION: IMMEDIATE RECOUNT
#
# 52. PART: BB5X5WH
#      DESCRIPTION: 5 X 5 WHT/CLEAR BOLT BAG ONLY
#      PLANNER: 01HDWA
#      EXPECTED: 2,515 | FOUND: 3,126 | DIFF: 611
#      VARIANCE: 24.3% | ACTION: IMMEDIATE RECOUNT
#
# 53. PART: TG018L216
#      DESCRIPTION: 18FT 0IN 2TG TOP EXTRUSION
#      PLANNER: 01TG1A
#      EXPECTED: 337 | FOUND: 258 | DIFF: -79
#      VARIANCE: -23.4% | ACTION: IMMEDIATE RECOUNT
#
# 54. PART: ES21290
#      DESCRIPTION: 1 7/8X21X290 ES INS W/TAPE
#      PLANNER: 01LAMA
#      EXPECTED: 108 | FOUND: 83 | DIFF: -25
#      VARIANCE: -23.1% | ACTION: IMMEDIATE RECOUNT
#
# 55. PART: BBAM08S
#      DESCRIPTION: 8-S ANGLE MT LEG IN BAG 8 HI
#      PLANNER: 01HDWA
#      EXPECTED: 20 | FOUND: 24 | DIFF: 4
#      VARIANCE: 20.0% | ACTION: IMMEDIATE RECOUNT
#
# 56. PART: BBAM16W
#      DESCRIPTION: 16-W ANGLE MT LEG OUT BAG 16HI
#      PLANNER: 01HDWA
#      EXPECTED: 26 | FOUND: 31 | DIFF: 5
#      VARIANCE: 19.2% | ACTION: IMMEDIATE RECOUNT
#
# 57. PART: EVWS300
#      DESCRIPTION: VINYL WINDOW SCREW 3IN
#      PLANNER: 01LTEA
#      EXPECTED: 39,226 | FOUND: 31,700 | DIFF: -7,526
#      VARIANCE: -19.2% | ACTION: IMMEDIATE RECOUNT
#
# 58. PART: FV201BL146
#      DESCRIPTION: 12FT2 FV 2IN WIDE RAIL BLK
#      PLANNER: 01FVWA
#      EXPECTED: 49 | FOUND: 40 | DIFF: -9
#      VARIANCE: -18.4% | ACTION: IMMEDIATE RECOUNT
#
# 59. PART: nan
#      DESCRIPTION: 6 5/8 END BRG PT RESI LHR REAR
#      PLANNER: 01TRKA
#      EXPECTED: 121 | FOUND: 99 | DIFF: -22
#      VARIANCE: -18.2% | ACTION: IMMEDIATE RECOUNT
#
# 60. PART: 37560051RNC
#      DESCRIPTION: 375X6X51 RHW NO CONES
#      PLANNER: 01SPRA
#      EXPECTED: 22 | FOUND: 18 | DIFF: -4
#      VARIANCE: -18.2% | ACTION: IMMEDIATE RECOUNT
#
# 61. PART: ES24290
#      DESCRIPTION: 1 7/8X24X290 ES INS W/TAPE
#      PLANNER: 01LAMA
#      EXPECTED: 122 | FOUND: 100 | DIFF: -22
#      VARIANCE: -18.0% | ACTION: IMMEDIATE RECOUNT
#
# 62. PART: TG084L170
#      DESCRIPTION: 14FT 2IN 2TG BOTTOM EXTRUSION
#      PLANNER: 01TG1A
#      EXPECTED: 672 | FOUND: 559 | DIFF: -113
#      VARIANCE: -16.8% | ACTION: IMMEDIATE RECOUNT
#
# 63. PART: BBJB08W
#      DESCRIPTION: 8-J JAMB BRACKET  BAG 8 HI
#      PLANNER: 01HDWA
#      EXPECTED: 24 | FOUND: 20 | DIFF: -4
#      VARIANCE: -16.7% | ACTION: IMMEDIATE RECOUNT
#
# 64. PART: CLSHDW21
#      DESCRIPTION: CLASSIC HINGES WIDE
#      PLANNER: 01HDWA
#      EXPECTED: 244 | FOUND: 204 | DIFF: -40
#      VARIANCE: -16.4% | ACTION: IMMEDIATE RECOUNT
#
# 65. PART: 37560051LNC
#      DESCRIPTION: 375X6X51 LHW NO CONES
#      PLANNER: 01SPRA
#      EXPECTED: 25 | FOUND: 21 | DIFF: -4
#      VARIANCE: -16.0% | ACTION: IMMEDIATE RECOUNT
#
# 66. PART: AUTOLATKT
#      DESCRIPTION: SINGLE AUTO LATCH KIT (NO TH)
#      PLANNER: 01HDWA
#      EXPECTED: 78 | FOUND: 66 | DIFF: -12
#      VARIANCE: -15.4% | ACTION: IMMEDIATE RECOUNT
#
# 🟡 MEDIUM PRIORITY - REVIEW RECOMMENDED (27 items)
# =================================================================
#
#  1. PART: ES21290
#      DESCRIPTION: 1 7/8X21X290 ES INS W/TAPE
#      PLANNER: 01LAMA
#      EXPECTED: 83 | FOUND: 95 | DIFF: 12
#      VARIANCE: 14.5% | ACTION: SPOT CHECK
#
#  2. PART: TG018L170
#      DESCRIPTION: 14FT 2IN 2TG TOP EXTRUSION
#      PLANNER: 01TG1A
#      EXPECTED: 837 | FOUND: 724 | DIFF: -113
#      VARIANCE: -13.5% | ACTION: SPOT CHECK
#
#  3. PART: TG084L242
#      DESCRIPTION: 20FT 2IN 2TG BOTTOM EXTRUSION
#      PLANNER: 01TG1A
#      EXPECTED: 976 | FOUND: 853 | DIFF: -123
#      VARIANCE: -12.6% | ACTION: SPOT CHECK
#
#  4. PART: CLSHDW18
#      DESCRIPTION: CLASSIC HINGES NARROW
#      PLANNER: 01HDWA
#      EXPECTED: 627 | FOUND: 548 | DIFF: -79
#      VARIANCE: -12.6% | ACTION: SPOT CHECK
#
#  5. PART: BBSPCRBLM
#      DESCRIPTION: M- CB BAG SOLID WOOD 8 SPGS
#      PLANNER: 01HDWA
#      EXPECTED: 8 | FOUND: 7 | DIFF: -1
#      VARIANCE: -12.5% | ACTION: SPOT CHECK
#
#  6. PART: CL3005L98
#      DESCRIPTION: 3 X 21 X 97 3/4 INSULATION
#      PLANNER: 01LAMA
#      EXPECTED: 104 | FOUND: 117 | DIFF: 12
#      VARIANCE: 11.7% | ACTION: SPOT CHECK
#
#  7. PART: AM07TR
#      DESCRIPTION: LM 7FT T-RAIL ONLY G1707
#      PLANNER: 01SHPA
#      EXPECTED: 447 | FOUND: 498 | DIFF: 51
#      VARIANCE: 11.4% | ACTION: SPOT CHECK
#
#  8. PART: BBFVLCX
#      DESCRIPTION: BOLTS AND NUTS FOR  LC (8 EA)
#      PLANNER: 01HDWA
#      EXPECTED: 879 | FOUND: 781 | DIFF: -98
#      VARIANCE: -11.1% | ACTION: SPOT CHECK
#
#  9. PART: TG084L216
#      DESCRIPTION: 18FT 0IN 2TG BOTTOM EXTRUSION
#      PLANNER: 01TG1A
#      EXPECTED: 280 | FOUND: 249 | DIFF: -31
#      VARIANCE: -11.1% | ACTION: SPOT CHECK
#
# 10. PART: TG018L144
#      DESCRIPTION: 12FT 0IN 2TG TOP EXTRUSION
#      PLANNER: 01TG1A
#      EXPECTED: 393 | FOUND: 433 | DIFF: 40
#      VARIANCE: 10.2% | ACTION: SPOT CHECK
#
# ... and 17 more medium priority items

# %%
today = datetime.now()
schedule_items = []

# Schedule HIGH priority items (spread over 3 days)
for idx, (_, item) in enumerate(high_priority.iterrows()):
    schedule_date = today + timedelta(days=(idx % 3) + 1)
    schedule_items.append({
        'Part_Number': item['Product number'],
        'Description': item['DESCRIPTION'],
        'Planner': item['PLANNER'],
        'Current_Qty': int(item['END']),
        'Expected_Qty': int(item['START']),
        'Variance_Pct': f"{item['VARIANCE']:.1%}",
        'Priority': 'HIGH',
        'Suggested_Date': schedule_date.strftime('%Y-%m-%d'),
        'Day_of_Week': schedule_date.strftime('%A'),
        'Action': 'FULL_RECOUNT',
        'Estimated_Time_Min': 30,
        'Notes': 'Immediate attention required'
    })

# Schedule MEDIUM priority items (spread over week 2)
for idx, (_, item) in enumerate(medium_priority.iterrows()):
    schedule_date = today + timedelta(days=7 + (idx % 7))
    schedule_items.append({
        'Part_Number': item['Product number'],
        'Description': item['DESCRIPTION'],
        'Planner': item['PLANNER'],
        'Current_Qty': int(item['END']),
        'Expected_Qty': int(item['START']),
        'Variance_Pct': f"{item['VARIANCE']:.1%}",
        'Priority': 'MEDIUM',
        'Suggested_Date': schedule_date.strftime('%Y-%m-%d'),
        'Day_of_Week': schedule_date.strftime('%A'),
        'Action': 'SPOT_CHECK',
        'Estimated_Time_Min': 15,
        'Notes': 'Review and verify count'
    })

# %%
schedule_df = pd.DataFrame(schedule_items)

# Export to CSV
filename = f"WestFargo_CycleCount_Schedule_{today.strftime('%Y%m%d')}.csv"
schedule_df.to_csv(filename, index=False)

print(f"✅ ERP scheduling file created: {filename}")
print(f"📊 Total items scheduled: {len(schedule_df)}")

# Show preview
print(f"\nPreview of scheduling file:")
print(schedule_df[['Part_Number', 'Planner', 'Priority', 'Suggested_Date', 'Action']].head(10))

# %%
# Workload summary by planner
print(f"\n👥 WORKLOAD DISTRIBUTION")
print("=" * 25)

workload_summary = schedule_df.groupby(['Planner', 'Priority']).agg({
    'Part_Number': 'count',
    'Estimated_Time_Min': 'sum'
}).round(0)

workload_summary.columns = ['Item_Count', 'Total_Minutes']

# Add total time in hours
workload_pivot = schedule_df.groupby('Planner').agg({
    'Part_Number': 'count',
    'Estimated_Time_Min': 'sum'
}).round(0)
workload_pivot['Total_Hours'] = (workload_pivot['Estimated_Time_Min'] / 60).round(1)
workload_pivot.columns = ['Total_Items', 'Total_Minutes', 'Total_Hours']

print("Workload by Planner:")
print(workload_pivot.sort_values('Total_Hours', ascending=False))

# %% [markdown]
# ## 5. Action Plans by Planner

# %%
print("\n📋 PLANNER-SPECIFIC ACTION PLANS")
print("=" * 35)

for planner in planner_stats.index:
    planner_data = planner_stats.loc[planner]
    planner_items = df_analysis[df_analysis['PLANNER'] == planner]
    
    print(f"\n{'='*50}")
    print(f"📝 ACTION PLAN: {planner}")
    print(f"{'='*50}")
    
    # Risk assessment and recommendations
    if planner in high_risk_planners:
        print("🔴 STATUS: HIGH RISK")
        print("🚨 IMMEDIATE ACTIONS REQUIRED:")
        print("   • Schedule training session within 48 hours")
        print("   • Implement daily supervisor checks")
        print("   • Review counting procedures step-by-step")
        print("   • Consider reassigning complex items temporarily")
        
    elif planner in medium_risk_planners:
        print("🟡 STATUS: MEDIUM RISK")
        print("📚 RECOMMENDED ACTIONS:")
        print("   • Provide refresher training this week")
        print("   • Weekly check-ins for next month")
        print("   • Review most problematic items together")
        
    else:
        print("🟢 STATUS: PERFORMING WELL")
        print("🌟 RECOGNITION:")
        print("   • Acknowledge excellent performance")
        print("   • Consider as mentor for other planners")
        print("   • May handle more complex items")
    
    # Specific problem items for this planner
    planner_high_items = planner_items[planner_items['VARIANCE_CATEGORY'] == 'HIGH']
    planner_medium_items = planner_items[planner_items['VARIANCE_CATEGORY'] == 'MEDIUM']
    
    if len(planner_high_items) > 0:
        print(f"\n🎯 HIGH PRIORITY ITEMS TO FOCUS ON:")
        for _, item in planner_high_items.head(5).iterrows():
            print(f"   • {item['Product number']}: {item['VARIANCE']:.1%} variance")
    
    if len(planner_medium_items) > 0:
        print(f"\n📋 MEDIUM PRIORITY ITEMS TO REVIEW:")
        for _, item in planner_medium_items.head(3).iterrows():
            print(f"   • {item['Product number']}: {item['VARIANCE']:.1%} variance")
    
    # Performance metrics
    print(f"\n📊 CURRENT PERFORMANCE:")
    print(f"   • Items managed: {int(planner_data['Total_Items'])}")
    print(f"   • High variance items: {int(planner_data['High_Variance_Count'])}")
    print(f"   • High variance rate: {planner_data['High_Variance_Rate']:.1f}%")
    print(f"   • Average variance: {planner_data['Avg_Abs_Variance']:.1%}")
    print(f"   • Risk score: {planner_data['Risk_Score']:.1f}")

# %% [markdown]
# ## 6. Executive Summary Export

# %%
print(f"\n📊 CREATING EXECUTIVE SUMMARY")
print("=" * 30)

# Create executive summary metrics
exec_summary = {
    'Analysis_Date': today.strftime('%Y-%m-%d'),
    'Location': 'WestFargo', 
    'Month_Analyzed': 'May 2025',
    'Total_Items_Analyzed': len(df_analysis),
    'High_Priority_Items': len(high_priority),
    'Medium_Priority_Items': len(medium_priority),
    'Low_Priority_Items': len(df_analysis[df_analysis['VARIANCE_CATEGORY'] == 'LOW']),
    'High_Risk_Planners': len(high_risk_planners),
    'Medium_Risk_Planners': len(medium_risk_planners),
    'Low_Risk_Planners': len(low_risk_planners),
    'Estimated_Recount_Hours': len(high_priority) * 0.5 + len(medium_priority) * 0.25,
    'Potential_Time_Savings_Pct': f"{len(df_analysis[df_analysis['VARIANCE_CATEGORY'] == 'LOW']) / len(df_analysis) * 100:.0f}%",
    'Overall_High_Variance_Rate': f"{len(high_priority) / len(df_analysis) * 100:.1f}%"
}

# Save executive summary
exec_df = pd.DataFrame([exec_summary])
exec_filename = f"WestFargo_Executive_Summary_{today.strftime('%Y%m%d')}.csv"
exec_df.to_csv(exec_filename, index=False)

print(f"✅ Executive summary saved: {exec_filename}")

print(f"\n📋 KEY METRICS:")
for key, value in exec_summary.items():
    if key != 'Analysis_Date':
        print(f"   • {key.replace('_', ' ')}: {value}")

# %%
print(f"\n🎉 ANALYSIS COMPLETE!")
print("=" * 25)

print(f"📁 FILES CREATED:")
print(f"   • {filename} (ERP scheduling)")
print(f"   • {exec_filename} (Executive summary)")

print(f"\n📈 NEXT STEPS:")
print("   1. Import scheduling file into ERP system")
print("   2. Meet with high-risk planners this week")
print("   3. Begin recounting high priority items")
print("   4. Re-run analysis next month with June data")

print(f"\n💡 KEY INSIGHT:")
high_variance_pct = len(high_priority) / len(df_analysis) * 100
low_variance_pct = len(df_analysis[df_analysis['VARIANCE_CATEGORY'] == 'LOW']) / len(df_analysis) * 100
print(f"   • {high_variance_pct:.0f}% of items need immediate attention")
print(f"   • {low_variance_pct:.0f}% of items are counting accurately (save time here!)")
print(f"   • Focus training on {len(high_risk_planners)} high-risk planners")

# %%
# Optional: Save the cleaned dataframe for future use
df_analysis.to_csv(f"WestFargo_CleanData_{today.strftime('%Y%m%d')}.csv", index=False)
print(f"\n💾 Bonus: Clean dataset saved as WestFargo_CleanData_{today.strftime('%Y%m%d')}.csv")
print("   (Use this for future analysis or comparison)")
# Out:
# ✅ ERP scheduling file created: WestFargo_CycleCount_Schedule_20250603.csv
# 📊 Total items scheduled: 93
#
# Preview of scheduling file:
#   Part_Number Planner Priority Suggested_Date        Action
# 0     EVWS112  01LTEA     HIGH     2025-06-04  FULL_RECOUNT
# 1   TG084L194  01TG1A     HIGH     2025-06-05  FULL_RECOUNT
# 2   TG018L146  01TG1A     HIGH     2025-06-06  FULL_RECOUNT
# 3     BBAM18W  01HDWA     HIGH     2025-06-04  FULL_RECOUNT
# 4     BBAM16S  01HDWA     HIGH     2025-06-05  FULL_RECOUNT
# 5         NaN  01LTEA     HIGH     2025-06-06  FULL_RECOUNT
# 6   TG084L194  01TG1A     HIGH     2025-06-04  FULL_RECOUNT
# 7         NaN  01HDWA     HIGH     2025-06-05  FULL_RECOUNT
# 8   TG018L194  01TG1A     HIGH     2025-06-06  FULL_RECOUNT
# 9     LM312HM  01BIFA     HIGH     2025-06-04  FULL_RECOUNT
#
# 👥 WORKLOAD DISTRIBUTION
# =========================
# Workload by Planner:
#          Total_Items  Total_Minutes  Total_Hours
# Planner
# 01HDWA            32            810         13.5
# 01TG1A            29            720         12.0
# 01LAMA            12            330          5.5
# 01LTEA             5            165          2.8
# 01SPRA             4            120          2.0
# 01FVWA             3             90          1.5
# 01TRKA             2             75          1.2
# 01BIFA             1             30          0.5
# 01PRSA             1             30          0.5
# 01SHPA             1             15          0.2
#
# 📋 PLANNER-SPECIFIC ACTION PLANS
# ===================================
#
# ==================================================
# 📝 ACTION PLAN: 01BIFA
# ==================================================
# 🔴 STATUS: HIGH RISK
# 🚨 IMMEDIATE ACTIONS REQUIRED:
#    • Schedule training session within 48 hours
#    • Implement daily supervisor checks
#    • Review counting procedures step-by-step
#    • Consider reassigning complex items temporarily
#
# 🎯 HIGH PRIORITY ITEMS TO FOCUS ON:
#    • LM312HM: -200.0% variance
#
# 📊 CURRENT PERFORMANCE:
#    • Items managed: 1
#    • High variance items: 1
#    • High variance rate: 100.0%
#    • Average variance: 200.0%
#    • Risk score: 300.0
#
# ==================================================
# 📝 ACTION PLAN: 01LTEA
# ==================================================
# 🔴 STATUS: HIGH RISK
# 🚨 IMMEDIATE ACTIONS REQUIRED:
#    • Schedule training session within 48 hours
#    • Implement daily supervisor checks
#    • Review counting procedures step-by-step
#    • Consider reassigning complex items temporarily
#
# 🎯 HIGH PRIORITY ITEMS TO FOCUS ON:
#    • EVWS112: 3005.6% variance
#    • EVWS300: -19.2% variance
#    • E1743WSBFONID: 148.3% variance
#    • OLD24X12GLS002: -100.0% variance
#    • nan: -400.0% variance
#
# 📋 MEDIUM PRIORITY ITEMS TO REVIEW:
#    • EVWS134: -7.0% variance
#
# 📊 CURRENT PERFORMANCE:
#    • Items managed: 15
#    • High variance items: 5
#    • High variance rate: 33.3%
#    • Average variance: 230.8%
#    • Risk score: 264.1
#
# ==================================================
# 📝 ACTION PLAN: 01TG1A
# ==================================================
# 🔴 STATUS: HIGH RISK
# 🚨 IMMEDIATE ACTIONS REQUIRED:
#    • Schedule training session within 48 hours
#    • Implement daily supervisor checks
#    • Review counting procedures step-by-step
#    • Consider reassigning complex items temporarily
#
# 🎯 HIGH PRIORITY ITEMS TO FOCUS ON:
#    • TG018L144: -163.8% variance
#    • TG018L146: -540.5% variance
#    • TG018L194: 100.0% variance
#    • TG084L144: 64.2% variance
#    • TG084L146: 194.2% variance
#
# 📋 MEDIUM PRIORITY ITEMS TO REVIEW:
#    • TG018L170: -13.5% variance
#    • TG084L216: -11.1% variance
#    • TG016L242: -9.3% variance
#
# 📊 CURRENT PERFORMANCE:
#    • Items managed: 41
#    • High variance items: 19
#    • High variance rate: 46.3%
#    • Average variance: 89.2%
#    • Risk score: 135.5
#
# ==================================================
# 📝 ACTION PLAN: 01LAMA
# ==================================================
# 🟡 STATUS: MEDIUM RISK
# 📚 RECOMMENDED ACTIONS:
#    • Provide refresher training this week
#    • Weekly check-ins for next month
#    • Review most problematic items together
#
# 🎯 HIGH PRIORITY ITEMS TO FOCUS ON:
#    • ASTRETFOAM: -43.2% variance
#    • ES21290: -23.1% variance
#    • ES24122: -86.8% variance
#    • ES24146: -65.6% variance
#    • CL3006L96: 62.3% variance
#
# 📋 MEDIUM PRIORITY ITEMS TO REVIEW:
#    • CL3005L98: 11.7% variance
#    • ES21290: 14.5% variance
#
# 📊 CURRENT PERFORMANCE:
#    • Items managed: 16
#    • High variance items: 10
#    • High variance rate: 62.5%
#    • Average variance: 38.5%
#    • Risk score: 101.0
#
# ==================================================
# 📝 ACTION PLAN: 01FVWA
# ==================================================
# 🟡 STATUS: MEDIUM RISK
# 📚 RECOMMENDED ACTIONS:
#    • Provide refresher training this week
#    • Weekly check-ins for next month
#    • Review most problematic items together
#
# 🎯 HIGH PRIORITY ITEMS TO FOCUS ON:
#    • FV201BL146: -18.4% variance
#    • FV201BL196: -63.5% variance
#    • FV201BL220: -100.0% variance
#
# 📊 CURRENT PERFORMANCE:
#    • Items managed: 5
#    • High variance items: 3
#    • High variance rate: 60.0%
#    • Average variance: 37.0%
#    • Risk score: 97.0
#
# ==================================================
# 📝 ACTION PLAN: 01SPRA
# ==================================================
# 🟢 STATUS: PERFORMING WELL
# 🌟 RECOGNITION:
#    • Acknowledge excellent performance
#    • Consider as mentor for other planners
#    • May handle more complex items
#
# 🎯 HIGH PRIORITY ITEMS TO FOCUS ON:
#    • 37560028LNC: -160.0% variance
#    • 37560028RNC: -160.0% variance
#    • 37560051LNC: -16.0% variance
#    • 37560051RNC: -18.2% variance
#
# 📊 CURRENT PERFORMANCE:
#    • Items managed: 12
#    • High variance items: 4
#    • High variance rate: 33.3%
#    • Average variance: 31.4%
#    • Risk score: 64.7
#
# ==================================================
# 📝 ACTION PLAN: 01HDWA
# ==================================================
# 🟢 STATUS: PERFORMING WELL
# 🌟 RECOGNITION:
#    • Acknowledge excellent performance
#    • Consider as mentor for other planners
#    • May handle more complex items
#
# 🎯 HIGH PRIORITY ITEMS TO FOCUS ON:
#    • AUTOLATKT: -15.4% variance
#    • BBAM08S: 20.0% variance
#    • BBAM14S: -43.8% variance
#    • BBAM14W: -55.8% variance
#    • BBAM16S: -500.0% variance
#
# 📋 MEDIUM PRIORITY ITEMS TO REVIEW:
#    • AUTOLATCAN: -9.6% variance
#    • BBAM10S: 10.0% variance
#    • BBFVLCX: -11.1% variance
#
# 📊 CURRENT PERFORMANCE:
#    • Items managed: 77
#    • High variance items: 21
#    • High variance rate: 27.3%
#    • Average variance: 33.9%
#    • Risk score: 61.2
#
# ==================================================
# 📝 ACTION PLAN: 01PRSA
# ==================================================
# 🟢 STATUS: PERFORMING WELL
# 🌟 RECOGNITION:
#    • Acknowledge excellent performance
#    • Consider as mentor for other planners
#    • May handle more complex items
#
# 🎯 HIGH PRIORITY ITEMS TO FOCUS ON:
#    • G047X4687GLNA: -140.0% variance
#
# 📊 CURRENT PERFORMANCE:
#    • Items managed: 4
#    • High variance items: 1
#    • High variance rate: 25.0%
#    • Average variance: 35.0%
#    • Risk score: 60.0
#
# ==================================================
# 📝 ACTION PLAN: 01TRKA
# ==================================================
# 🟢 STATUS: PERFORMING WELL
# 🌟 RECOGNITION:
#    • Acknowledge excellent performance
#    • Consider as mentor for other planners
#    • May handle more complex items
#
# 🎯 HIGH PRIORITY ITEMS TO FOCUS ON:
#    • CPMT011B: -25.0% variance
#    • nan: -18.2% variance
#
# 📋 MEDIUM PRIORITY ITEMS TO REVIEW:
#    • CPN033: -6.9% variance
#
# 📊 CURRENT PERFORMANCE:
#    • Items managed: 72
#    • High variance items: 2
#    • High variance rate: 2.8%
#    • Average variance: 0.9%
#    • Risk score: 3.7
#
# ==================================================
# 📝 ACTION PLAN: 01SHPA
# ==================================================
# 🟢 STATUS: PERFORMING WELL
# 🌟 RECOGNITION:
#    • Acknowledge excellent performance
#    • Consider as mentor for other planners
#    • May handle more complex items
#
# 📋 MEDIUM PRIORITY ITEMS TO REVIEW:
#    • AM07TR: 11.4% variance
#
# 📊 CURRENT PERFORMANCE:
#    • Items managed: 8
#    • High variance items: 0
#    • High variance rate: 0.0%
#    • Average variance: 2.1%
#    • Risk score: 2.1
#
# 📊 CREATING EXECUTIVE SUMMARY
# ==============================
# ✅ Executive summary saved: WestFargo_Executive_Summary_20250603.csv
#
# 📋 KEY METRICS:
#    • Location: WestFargo
#    • Month Analyzed: May 2025
#    • Total Items Analyzed: 255
#    • High Priority Items: 66
#    • Medium Priority Items: 27
#    • Low Priority Items: 162
#    • High Risk Planners: 3
#    • Medium Risk Planners: 2
#    • Low Risk Planners: 5
#    • Estimated Recount Hours: 39.75
#    • Potential Time Savings Pct: 64%
#    • Overall High Variance Rate: 25.9%
#
# 🎉 ANALYSIS COMPLETE!
# =========================
# 📁 FILES CREATED:
#    • WestFargo_CycleCount_Schedule_20250603.csv (ERP scheduling)
#    • WestFargo_Executive_Summary_20250603.csv (Executive summary)
#
# 📈 NEXT STEPS:
#    1. Import scheduling file into ERP system
#    2. Meet with high-risk planners this week
#    3. Begin recounting high priority items
#    4. Re-run analysis next month with June data
#
# 💡 KEY INSIGHT:
#    • 26% of items need immediate attention
#    • 64% of items are counting accurately (save time here!)
#    • Focus training on 3 high-risk planners
#
# 💾 Bonus: Clean dataset saved as WestFargo_CleanData_20250603.csv
#    (Use this for future analysis or comparison)
